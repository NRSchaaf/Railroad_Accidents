# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/NRSchaaf/Railroad_Accidents/refs/heads/main/RR_Accident_Weather_Data.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   reportingrailroadcode accidentnumber       date      time accidenttype  \
# 0                   CSX      000178042   8/7/2018  10:51 AM   Derailment
# 1                   CSX      000182665  4/30/2019  12:25 AM   Derailment
# 2                   CSX      000138406  12/3/2014  11:45 PM   Derailment
# 3                   CSX      000188525  2/19/2020   8:44 AM   Derailment
# 4                   CSX      000175393  3/24/2018  10:53 AM   Derailment
#
#    hazmatreleasedcars     station stateabbr  temperature  visibility_code  \
# 0                   0     BUFFALO        NY           73                2
# 1                   0    MILLBURY        OH           42                4
# 2                   0       PARMA        OH           35                4
# 3                   0  CINCINNATI        OH           25                2
# 4                   0        LIMA        OH           36                2
#
#    ... trainspeed equipmentdamagecost trackdamagecost totaldamagecost  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4595 entries, 0 to 4594
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   reportingrailroadcode     4595 non-null   object
#  1   accidentnumber            4595 non-null   object
#  2   date                      4595 non-null   object
#  3   time                      4595 non-null   object
#  4   accidenttype              4595 non-null   object
#  5   hazmatreleasedcars        4595 non-null   int64
#  6   station                   4595 non-null   object
#  7   stateabbr                 4595 non-null   object
#  8   temperature               4595 non-null   int64
#  9   visibility_code           4595 non-null   int64
#  10  visibility                4595 non-null   object
#  11  weathercondition          4595 non-null   object
#  12  tracktype                 4595 non-null   object
# ...

# %%
df.describe().T
# Out:
#                       count           mean            std        min  \
# hazmatreleasedcars   4595.0       0.028945       0.526021    0.00000
# temperature          4595.0      58.926877      22.587870  -35.00000
# visibility_code      4595.0       2.660936       1.035686    1.00000
# trainspeed           4595.0       9.551687      12.077753    0.00000
# equipmentdamagecost  4595.0  114259.902938  448682.514449    0.00000
# trackdamagecost      4595.0   67180.249837  202218.147279    0.00000
# totaldamagecost      4595.0  208355.717954  664294.973831    0.00000
# latitude             4595.0      37.919532       5.213919    0.00000
# longitude            4595.0     -92.067926      15.604322 -683.19219
# prior_temp           4595.0      57.591077      19.029285  -16.80000
# actual_temp          4595.0      57.371121      19.353664  -18.80000
# following_temp       4595.0      57.465484      19.380081  -21.20000
#
# ...

# %%
derailment_count = df[df['accidenttype'] == 'Derailment'].shape[0]
derailment_count
# Out:
# 4301
